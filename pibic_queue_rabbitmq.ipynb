# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosfcPinheiro/pibic-api-llm-integration/blob/main/pibic_queue_rabbitmq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Teste de requisições para LLMs utilizando padrão de Filas assíncronas
# O objetivo principal é testar e avaliar o tempo de resposta de requisições para uma API que interaja com LLMs, utilizando o padrão de filas assíncronas.
#
# ## Código e estrutura
# Para análise, são utilizados **8 prompts diferentes**, que buscam explorar diferentes tamanhos e temáticas de texto. Nesse script de teste, cada cliente/producer é responsável por enviar um prompt (uma request) para a fila de requests `request_summarize_queue`, sendo **30 clientes/producers** para cada prompt, onde são armazenado os tempos de resposta de todas as requests para cada prompt, respectivamente.
#
# O arquivo .csv que contém os dados de tempo da request é lido posteriormente para compor os dados de análise, que também são escritos em um outro csv.
#
# Além disso, cada conjunto de testes são executados utilizando **4 modelos diferentes**, que fundamentalmente são especializados em sumarização, mas com objetivos diferentes. Os modelos utilizados são:
#
# - facebook/bart_large_cnn
# - google/pegasus_cnn_dailymail
# - knkarthick/MEETING_SUMMARY
# - google/pegasus_xsum
#
# O worker/consumer é o responsável por receber as mensagens (corpo das requests) da fila `request_summarize_queue`, processar, realizar a request para a API gateway de LLM, e devolver a resposta para o cliente, publicando a resposta em sua fila de respostas exclusiva.
#
# ## Padrões e bibliotecas
# O padrão a ser utilizado é o de **Filas assíncronas**, dado que utiliza uma fila de mensagens (request_summarize_queue) com diferentes clientes/producers atuando em **threads únicas**.
#
# As principais bibliotecas utilizadas são:
# - time (funções de manipulação de tempo)
# - requests (envio de requisições HTTP)
# - csv (manipulação de arquivos csv)
# - statistics (funções para cálculos estatísticos)
# - numpy (funções para manipulação de arrays e matrizes)
# - pika (SDK python do RabbitMQ)
# - threading (gerenciamento de threads)
#
# ## Métricas analisadas
# As métricas utilizadas para análise do tempo de resposta da requisição para cada prompt foram as seguintes:
# - Média de tempo (tempo médio de resposta das requisições)
# - Máximo e Mínimo (tempo com valores máximos e mínimos)
# - Desvio padrão (dispersão absoluta dos dados em relação à média, numericamente)
# - Coeficiente de variação (dispersão relativa dos dados em relação à média, em  porcentagem)
# - Percentil - 95% e 99% (valores abaixo do qual uma certa porcentagem dos tempos se encontram)
#
# > Todas as métricas levam em consideração a unidade de segundos para o tempo de resposta da requisição

# %%
# !apt-get update
# !apt-get install rabbitmq-server -y
# !service rabbitmq-server start
# !pip install pika --upgrade
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,170 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,615 kB]
# Fetched 6,169 kB in 3s (2,340 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# rabbitmq-server is already the newest version (3.9.27-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
#  * Starting RabbitMQ Messaging Server rabbitmq-server
#  * RabbitMQ Messaging Server already running
#    ...done.
# Requirement already satisfied: pika in /usr/local/lib/python3.12/dist-packages (1.3.2)

# %%
# !sudo rabbitmqctl list_queues
# Out:
# Timeout: 60.0 seconds ...
# Listing queues for vhost / ...
# name	messages
# request_summarize_queue	34

# %%
# Definição dos prompts de teste, modelo, endpoint e custo ==========================
# modelo utilizado para as requisições (alterar variável para troca de modelo)
API_URL = "https://zetta-faunlike-kindheartedly.ngrok-free.dev"
MODEL = "facebook_bart_large_cnn"
ENDPOINT_TEST = f"{API_URL}/summarize?model={MODEL}"
# custo por inferência (preço base, em $, tomando em média por modelos como BART e PEGASUS)
BASE_PRICE_PER_1K_TOKENS = 0.0006

PROMPTS = [
    """Solar energy is one of the most promising renewable sources for the planet’s future. With concerns about climate change and the need to reduce fossil fuel dependence, many countries are investing in clean technologies. Brazil has one of the largest solar potentials, especially in the Northeast and Midwest, where radiation is high year-round. The installation of solar panels in homes and businesses has grown, driven by incentives and lower equipment costs. Distributed generation allows consumers to also produce energy, helping decentralize the electricity system. Challenges remain, such as infrastructure, storage, and stronger public policies, but with technology and social engagement, solar energy is set to play an increasingly important role in Brazil’s energy matrix.""",

    """The city of Ouro Preto, located in the state of Minas Gerais, is one of the greatest symbols of Brazilian colonial architecture and history. Founded in the 17th century during the gold rush, it quickly became one of the main economic centers of the Portuguese colony, attracting thousands of people in search of wealth. Its stone streets, steep slopes, and preserved buildings reveal a past marked by opulence, religiosity, and resistance. Ouro Preto is home to some of the most impressive baroque churches in Brazil, such as the Church of Saint Francis of Assisi, designed by Aleijadinho and decorated with works by Mestre Ataíde. The city was also the stage for important events of the Inconfidência Mineira, a movement that sought Brazil’s independence from Portugal. Today, the city is recognized as a UNESCO World Heritage Site, attracting tourists interested in history, art, and culture. In addition to its historical value, Ouro Preto has a vibrant university life thanks to the Federal University of Ouro Preto (UFOP) and hosts various festivals of art, music, and cinema throughout the year. This combination of tradition and youth makes the city a unique place where past and present coexist in harmony.""",

    """Artificial intelligence (AI) is one of the most transformative technologies of the 21st century. It impacts medicine, education, industry, and commerce, improving efficiency and user experience. At the same time, AI raises ethical concerns about data use, bias, and its impact on jobs. Governments and society must ensure its benefits are distributed fairly and responsibly.""",

    """Classical music, although it emerged centuries ago, continues to influence contemporary composers. Works by Beethoven, Mozart, and Bach are studied in conservatories and reinterpreted in different musical styles. This tradition shows how art can transcend generations and reinvent itself.""",

    """The history of the internet began in the 1960s with military projects in the United States, evolving into academic networks and later into commercial use. Today, the internet connects billions of people in real time, transforming the way we work, study, and interact. Digital platforms enable instant communication, e-commerce, and unlimited access to information. However, problems also arise, such as fake news, cybercrime, and technological dependence. The future of the internet depends on balanced regulations, continuous innovation, and digital education so that its benefits can be enjoyed safely and inclusively.""",

    """Coffee is one of the most consumed beverages in the world and is part of Brazilian culture.""",

    """The Olympic Games are more than just a sporting event; they represent a celebration of unity, diversity, and human achievement. Athletes from around the world gather to compete at the highest level, showcasing not only physical skill but also resilience and determination. The Games have evolved over time, incorporating new disciplines and promoting values such as fair play and respect. Beyond the competitions, the Olympics foster cultural exchange, allowing nations to share traditions and build mutual understanding. Despite challenges such as political tensions and financial costs, the spirit of the Olympics continues to inspire millions, proving that sport can be a powerful force for peace and cooperation.""",

    """The Renaissance was a period of profound cultural, artistic, and scientific transformation in Europe between the 14th and 17th centuries. It marked the rediscovery of classical knowledge and the flourishing of human creativity. Artists like Leonardo da Vinci and Michelangelo produced masterpieces that continue to inspire admiration today, while scientists such as Galileo challenged traditional views of the universe. The invention of the printing press by Gutenberg revolutionized the spread of ideas, making books more accessible and fueling intellectual debates."""
]

# %%
# Implementação do AutoTokenizer para contagem de tokens ===============
from transformers import AutoTokenizer

# mapeamento exato entre a variável MODEL e o Hugging Face Hub para o tokenizer
MODEL_TOKENIZER_MAP = {
    "facebook_bart_large_cnn": "facebook/bart-large-cnn",
    "google_pegasus_cnn_dailymail": "google/pegasus-cnn_dailymail",
    "knkarthick_MEETING_SUMMARY": "knkarthick/MEETING_SUMMARY",
    "google_pegasus_xsum": "google/pegasus-xsum"
}
repo_id = MODEL_TOKENIZER_MAP.get(MODEL)
tokenizer = AutoTokenizer.from_pretrained(repo_id)

print(f"Modelo carregado para o Tokenizer")
print(f"Repository id: {repo_id}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Modelo carregado para o Tokenizer
# Repository id: google/pegasus-xsum

# %%
# Definição de funções para contagem e calculo baseado em tokens
# função para contagem dos tokens
def get_token_count(prompt):
  if not prompt: return 0
  return len(tokenizer.encode(prompt))

# função para calculo estimado de custo baseado nos tokens de entrada e saída
def calc_estimated_cost(prompt, output):
  # Conta tokens reais de entrada e saída
  tokens_in = len(tokenizer.encode(prompt))
  tokens_out = len(tokenizer.encode(output))
  total_tokens = tokens_in + tokens_out

  # Calcula o custo proporcional
  cost = (total_tokens / 1000) * BASE_PRICE_PER_1K_TOKENS
  return total_tokens, cost

# %%
# Estabelecer conexão com RabbitMQ
def get_connection():
  # retorna 'connection' com o cliente localhost do RabbitMQ
  return pika.BlockingConnection(pika.ConnectionParameters('localhost'))

# %%
# Função de requisição para o api gateway dos modelos =======================
import time, requests

def summarizer(prompt: str, client_id: int):
  try:
    response = requests.post(ENDPOINT_TEST, json={"text": prompt})
    summary = response.json()["summary"]
    # Calcula a contagem de tokens para satisfazer o desempacotamento do consumer
    tokens_in = get_token_count(prompt)

    return summary, tokens_in
  except Exception as e:
    print(f"\033[91m[ERROR]\033[0m Houve um problema na requisição do client-{client_id}: {e}")
    return "Erro no processamento", 0

# %%
# Criação de classe utilitária de simulação de cliente/producer ================
import uuid, json, time

QUEUE_NAME = "request_summarize_queue"

class Client:
  def __init__(self, client_id):
    # atributos de cliente/producer
    self.client_id = client_id
    self.connection = get_connection()
    self.channel = self.connection.channel()
    self.response = None

    # declara uma queue exclusiva e temporária, response queue
    result = self.channel.queue_declare(queue='', exclusive=True)
    self.callback_queue = result.method.queue

    # informando ao RabbitMQ que deve executar essa função ao receber uma nova mensagem
    self.channel.basic_consume(
        queue=self.callback_queue,
        on_message_callback=self.on_response,
        auto_ack=True
    )

  # função callback para receber a resposta da response queue
  def on_response(self, ch, method, props, body) -> None:
    if self.corr_id == props.correlation_id:
      self.response = body

  # função que simula uma requisição RPC
  def call(self, prompt: str, prompt_id: int) -> dict:
    self.response = None
    self.corr_id = str(uuid.uuid4())

    # registro do Timestamp de Envio (Início da Latência E2E)
    start_time = time.time()

    # adicionando o prompt_id ao payload para facilitar o rastreio no log
    payload = {
        "client_id": self.client_id,
        "prompt_id": prompt_id,
        "prompt": prompt
    }

    self.channel.basic_publish(
        exchange='',
        routing_key=QUEUE_NAME,
        properties=pika.BasicProperties(
            reply_to=self.callback_queue,
            correlation_id=self.corr_id
        ),
        body=json.dumps(payload)
    )

    # loop de espera (bloqueante, simulando o comportamento síncrono para o cliente)
    while self.response is None:
      self.connection.process_data_events()

    # registro do Timestamp de Conclusão
    end_time = time.time()

    # Retornamos um dicionário com os dados necessários para o CSV de métricas
    return {
        "prompt_id": prompt_id,
        "response": self.response,
        "start_timestamp": start_time,
        "end_timestamp": end_time
    }

# %%
# Declarando Consumer (worker) =======================
import pika, time, json

# função para definição do consumer (worker) da request_summarize_queue
def consumer():
  connection = get_connection()
  channel = connection.channel()
  # verificar se a queue existe de forma idempotente (é uma boa prática, nesse caso, repetir o código de declaração da queue)
  channel.queue_declare(queue=QUEUE_NAME, durable=True)

  # função callback que será chamada quando uma message for recebida
  def callback(ch, method, props, body):
    payload = json.loads(body)
    client_id = payload["client_id"]
    prompt = payload["prompt"]

    # Adição para novas métricas ---
    # Captura o prompt_id enviado pelo Producer para rastreio no log final
    prompt_id = payload.get("prompt_id")

    print(f"\033[94m[Consumer]\033[0m Processando a request do cliente-{client_id}")

    # Alteração necessária no summarizer
    # A função summarizer agora deve retornar uma tupla: (texto_do_resumo, contagem_de_tokens)
    summary, tokens_in = summarizer(prompt, client_id)

    # Resposta expandida com metadados de custo e ID
    response = {
        "client_id": client_id,
        "prompt_id": prompt_id, # Retorna o ID para o Producer
        "summary": summary,
        "tokens_input": tokens_in # Retorna a contagem para cálculo de custo
    }

    # publica a resposta na queue individual do cliente
    channel.basic_publish(
        exchange='',
        routing_key=props.reply_to,
        properties=pika.BasicProperties(correlation_id=props.correlation_id),
        body=json.dumps(response)
    )
    print(f"\033[94m[Consumer]\033[0m Request enviada do cliente-{client_id} para a queue {QUEUE_NAME}\n")
    ch.basic_ack(delivery_tag=method.delivery_tag)

  channel.basic_qos(prefetch_count=1)
  # informando ao RabbitMQ que essa função callback deve receber messages
  channel.basic_consume(
      queue=QUEUE_NAME,
      auto_ack=False,
      on_message_callback=callback
  )

  print('\033[94m[Consumer]\033[0m Aguardando messages...\n')
  channel.start_consuming()

# %%
# Função para salvar tempo das requisições de um determinado prompt em .csv =======================
import csv, os

FOLDER = "raw"
CSV_REQ_TIMES = f"./{FOLDER}/raw_data_requests_{MODEL}.csv"

def save_times_csv(request_response_data: list) -> None:
    """
    Salva a lista de resultados das requisições no CSV.
    Note: 'request_response_data' deve ser uma lista de dicionários.
    """
    os.makedirs(FOLDER, exist_ok=True)

    # Cabeçalhos atualizados para o Plano de Métricas Científicas
    fieldnames = [
        "prompt_id",
        "req_id",
        "prompt_entrada",
        "saida_resposta",
        "tokens_in",
        "tokens_out",
        "custo_usd",
        "tempo_s"
    ]

    # Usamos 'a' (append) ou 'w' (write) dependendo se você limpa o arquivo a cada prompt
    # Como no loop anterior já gerencia o arquivo, aqui se mantem a lógica de escrita
    with open(CSV_REQ_TIMES, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(request_response_data)

    print(f"\n\033[93m[SYSTEM]\033[0m Dados brutos de performance do modelo {MODEL} salvos em: {CSV_REQ_TIMES}")

# %%
# Execução do consumer e bateria de testes ===========
import threading, time, json

# 1. Configurações Globais
CLIENTS_QUANT = 30
REQUEST_RESPONSE_DATAS = []
BASE_PRICE_PER_1K_TOKENS = 0.0006  # Valor base para estimativa pibic

def run_client(client, prompt: str, prompt_id: int, request_response_datas: list) -> None:
    try:
        start_req = time.time()

        # O retorno é um dicionário: {"response": bytes, "start_timestamp": float}
        result_dict = client.call(prompt, prompt_id)

        end_req = time.time()
        request_time = round(end_req - start_req, 4)

        # Decodificação segura da resposta vinda da fila
        summary_response = json.loads(result_dict["response"].decode("utf-8"))
        summary_text = summary_response["summary"]

        # Métricas de Tokenização
        t_in = get_token_count(prompt)
        t_out = get_token_count(summary_text)

        # Cálculo de Custo Estimado
        custo_req = round(((t_in + t_out) / 1000) * BASE_PRICE_PER_1K_TOKENS, 6)

        # Armazenamento dos dados brutos
        request_response_datas.append({
            "prompt_id": prompt_id + 1,
            "req_id": client.client_id,
            "prompt_entrada": prompt,
            "saida_resposta": summary_text,
            "tokens_in": t_in,
            "tokens_out": t_out,
            "custo_usd": custo_req,
            "tempo_s": request_time
        })

        # Log de progresso individual por thread
        print(f"  └─ [Thread-{client.client_id}] Concluído em {request_time}s")

    except Exception as e:
        print(f"  └─ \033[91m[ERRO Client-{client.client_id}]\033[0m {e}")

# Iniciar o consumer em background (daemon para fechar com o script)
threading.Thread(target=consumer, daemon=True).start()

total_prompts = len(PROMPTS)

for idx, prompt in enumerate(PROMPTS):
    current_p = idx + 1
    print("\n" + "="*60)
    print(f" \033[94m[PROMPT {current_p}/{total_prompts}]\033[0m Iniciando bateria de {CLIENTS_QUANT} testes paralelos...")
    print(f" Conteúdo: {prompt[:50]}...")
    print("="*60)

    # Criação das threads dos clientes
    clients = [Client(i) for i in range(CLIENTS_QUANT)]
    threads = []

    for c in clients:
        t = threading.Thread(target=run_client, args=(c, prompt, idx, REQUEST_RESPONSE_DATAS))
        threads.append(t)
        t.start()

    # Barreira de sincronização: aguarda todas as 30 threads do prompt atual
    for t in threads:
        t.join()

    print(f"\033[92m [CHECK]\033[0m Bateria do Prompt {current_p} finalizada com sucesso.\n")

# Após todos os prompts, salva o consolidado
save_times_csv(REQUEST_RESPONSE_DATAS)

print("\n" + "#"*60)
print(f" \033[92m[FINALIZADO]\033[0m Todos os testes foram concluídos e salvos.")
print("#"*60)
# Out:
# ============================================================
#  [PROMPT 1/8] Iniciando bateria de 30 testes paralelos...
#  Conteúdo: Solar energy is one of the most promising renewabl...
# ============================================================
# [Consumer] Aguardando messages...
#
# [Consumer] Processando a request do cliente-27
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-29
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-28
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-1
# [Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-0
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-2
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-3
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-6
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-4
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-5
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-7
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-8
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-9
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-10
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-11
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-13
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-12
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-15
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-16
# [Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-17
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-18
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-19
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-20
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-21
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-22
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-23
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-26
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-25
# [Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-27
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-28
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-29
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-2
#   └─ [Thread-2] Concluído em 100.4711s
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-1
# [Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-0
#   └─ [Thread-1] Concluído em 103.3176s
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
#   └─ [Thread-0] Concluído em 105.9512s
# [Consumer] Processando a request do cliente-4
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
#   └─ [Thread-4] Concluído em 110.1403s
# [Consumer] Processando a request do cliente-3
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-6
#   └─ [Thread-3] Concluído em 114.0165s
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-5
#   └─ [Thread-6] Concluído em 116.3627s
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-7
#   └─ [Thread-5] Concluído em 118.6258s
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#   └─ [Thread-7] Concluído em 121.5591s
#
# [Consumer] Processando a request do cliente-8
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-9
#   └─ [Thread-8] Concluído em 124.8068s
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#   └─ [Thread-9] Concluído em 127.5243s
#
# [Consumer] Processando a request do cliente-10
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-11
#   └─ [Thread-10] Concluído em 130.1062s
#   └─ [Thread-11] Concluído em 131.9067s
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
#   └─ [Thread-14] Concluído em 133.865s
# [Consumer] Processando a request do cliente-13
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-12
#   └─ [Thread-13] Concluído em 136.4159s
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
#   └─ [Thread-12] Concluído em 139.077s
# [Consumer] Processando a request do cliente-15
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
#   └─ [Thread-15] Concluído em 141.7684s
# [Consumer] Processando a request do cliente-16
# [Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-17
#   └─ [Thread-16] Concluído em 143.7922s
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-18
#   └─ [Thread-17] Concluído em 145.4888s
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#
#   └─ [Thread-18] Concluído em 147.9889s
# [Consumer] Processando a request do cliente-21
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-19
#   └─ [Thread-21] Concluído em 150.3973s
#   └─ [Thread-19] Concluído em 152.2973s[Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
#
# [Consumer] Processando a request do cliente-20
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
#   └─ [Thread-20] Concluído em 154.5498s
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-22
#   └─ [Thread-24] Concluído em 156.1293s
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
#   └─ [Thread-22] Concluído em 158.0647s
# [Consumer] Processando a request do cliente-23
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-25
#   └─ [Thread-23] Concluído em 159.6923s
# [Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-28
#   └─ [Thread-25] Concluído em 161.6834s
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
#   └─ [Thread-28] Concluído em 163.1911s
# [Consumer] Processando a request do cliente-27
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#   └─ [Thread-27] Concluído em 165.1258s
#
# [Consumer] Processando a request do cliente-26
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-29
#   └─ [Thread-26] Concluído em 167.2897s
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
#   └─ [Thread-29] Concluído em 168.9324s
#  [CHECK] Bateria do Prompt 1 finalizada com sucesso.
#
#
# ============================================================
#  [PROMPT 2/8] Iniciando bateria de 30 testes paralelos...
#  Conteúdo: The city of Ouro Preto, located in the state of Mi...
# ============================================================
# [Consumer] Processando a request do cliente-1
# [Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
#   └─ [Thread-1] Concluído em 3.3605s
# [Consumer] Processando a request do cliente-0
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-2
#   └─ [Thread-0] Concluído em 7.8611s
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-4
#   └─ [Thread-2] Concluído em 11.626s
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-3
#   └─ [Thread-4] Concluído em 15.2983s
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-5
#   └─ [Thread-3] Concluído em 19.0979s
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-6
#   └─ [Thread-5] Concluído em 23.8309s
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-7
#   └─ [Thread-6] Concluído em 27.5902s
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#
#   └─ [Thread-7] Concluído em 31.0741s
# [Consumer] Processando a request do cliente-9
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#
#   └─ [Thread-9] Concluído em 34.4827s
# [Consumer] Processando a request do cliente-8
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
#   └─ [Thread-8] Concluído em 38.7154s
# [Consumer] Processando a request do cliente-10
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-12
#   └─ [Thread-10] Concluído em 42.6192s
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-13
#   └─ [Thread-12] Concluído em 46.8564s
#   └─ [Thread-13] Concluído em 50.487s
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-11
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
#   └─ [Thread-11] Concluído em 55.0176s
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-16
#   └─ [Thread-14] Concluído em 57.7124s
# [Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-15
#   └─ [Thread-16] Concluído em 60.9391s
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-17
#   └─ [Thread-15] Concluído em 64.1844s
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
#   └─ [Thread-17] Concluído em 67.1087s
# [Consumer] Processando a request do cliente-18
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#
#   └─ [Thread-18] Concluído em 70.2488s
# [Consumer] Processando a request do cliente-19
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
#   └─ [Thread-19] Concluído em 72.8765s
# [Consumer] Processando a request do cliente-20
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-21
#   └─ [Thread-20] Concluído em 76.2009s
#   └─ [Thread-21] Concluído em 80.1928s
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-22
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
#   └─ [Thread-22] Concluído em 83.6781s
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-25
#   └─ [Thread-24] Concluído em 86.7012s
# [Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
#   └─ [Thread-25] Concluído em 89.9304s
# [Consumer] Processando a request do cliente-23
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#
#   └─ [Thread-23] Concluído em 92.8503s
# [Consumer] Processando a request do cliente-27
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
#   └─ [Thread-27] Concluído em 95.8457s
# [Consumer] Processando a request do cliente-26
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
#   └─ [Thread-26] Concluído em 98.9024s
# [Consumer] Processando a request do cliente-28
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
#   └─ [Thread-28] Concluído em 101.7692s
# [Consumer] Processando a request do cliente-29
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
#   └─ [Thread-29] Concluído em 104.776s
#  [CHECK] Bateria do Prompt 2 finalizada com sucesso.
#
#
# ============================================================
#  [PROMPT 3/8] Iniciando bateria de 30 testes paralelos...
#  Conteúdo: Artificial intelligence (AI) is one of the most tr...
# ============================================================
# [Consumer] Processando a request do cliente-0
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#   └─ [Thread-0] Concluído em 2.6038s
#
# [Consumer] Processando a request do cliente-1
#   └─ [Thread-1] Concluído em 6.2673s[Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
#
# [Consumer] Processando a request do cliente-2
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-4
#   └─ [Thread-2] Concluído em 8.3753s
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-3
#   └─ [Thread-4] Concluído em 10.4126s
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-5
#   └─ [Thread-3] Concluído em 13.1455s
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-6
#   └─ [Thread-5] Concluído em 16.9829s
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-7
#   └─ [Thread-6] Concluído em 20.3559s
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#
#   └─ [Thread-7] Concluído em 22.3957s
# [Consumer] Processando a request do cliente-10
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
#   └─ [Thread-10] Concluído em 24.2935s
# [Consumer] Processando a request do cliente-8
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
#   └─ [Thread-8] Concluído em 26.6943s
# [Consumer] Processando a request do cliente-9
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-11
#   └─ [Thread-9] Concluído em 29.8561s
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
#   └─ [Thread-11] Concluído em 32.4944s
# [Consumer] Processando a request do cliente-12
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
#   └─ [Thread-12] Concluído em 35.172s
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-13
#   └─ [Thread-14] Concluído em 37.0483s
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-16
#   └─ [Thread-13] Concluído em 39.078s
#   └─ [Thread-16] Concluído em 41.2987s[Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
#
# [Consumer] Processando a request do cliente-15
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
#   └─ [Thread-15] Concluído em 43.1027s
# [Consumer] Processando a request do cliente-18
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-17
#   └─ [Thread-18] Concluído em 44.9747s
#   └─ [Thread-17] Concluído em 47.3002s
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-19
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-20
#   └─ [Thread-19] Concluído em 49.2525s
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
#   └─ [Thread-20] Concluído em 50.7186s
# [Consumer] Processando a request do cliente-21
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
#   └─ [Thread-21] Concluído em 51.7732s
# [Consumer] Processando a request do cliente-22
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-23
#   └─ [Thread-22] Concluído em 53.6622s
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-24
#   └─ [Thread-23] Concluído em 55.8309s
#   └─ [Thread-24] Concluído em 56.9596s[Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
#
# [Consumer] Processando a request do cliente-25
# [Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-26
#   └─ [Thread-25] Concluído em 59.205s
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-27
#   └─ [Thread-26] Concluído em 61.0061s
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
#   └─ [Thread-27] Concluído em 62.4311s
# [Consumer] Processando a request do cliente-29
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-28
#   └─ [Thread-29] Concluído em 63.0482s
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
#   └─ [Thread-28] Concluído em 64.5565s
#  [CHECK] Bateria do Prompt 3 finalizada com sucesso.
#
#
# ============================================================
#  [PROMPT 4/8] Iniciando bateria de 30 testes paralelos...
#  Conteúdo: Classical music, although it emerged centuries ago...
# ============================================================
# [Consumer] Processando a request do cliente-2
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#   └─ [Thread-2] Concluído em 3.6716s
#
# [Consumer] Processando a request do cliente-0
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-4
#   └─ [Thread-0] Concluído em 7.7012s
#   └─ [Thread-4] Concluído em 10.189s
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-1
# [Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-8
#   └─ [Thread-1] Concluído em 12.339s
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
#   └─ [Thread-8] Concluído em 14.5806s
# [Consumer] Processando a request do cliente-3
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
#   └─ [Thread-3] Concluído em 18.6567s
# [Consumer] Processando a request do cliente-6
#   └─ [Thread-6] Concluído em 21.8471s
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-5
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
#   └─ [Thread-5] Concluído em 25.0353s
# [Consumer] Processando a request do cliente-9
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#   └─ [Thread-9] Concluído em 27.405s
#
# [Consumer] Processando a request do cliente-7
#   └─ [Thread-7] Concluído em 29.9179s
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-11
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
#   └─ [Thread-11] Concluído em 32.357s
# [Consumer] Processando a request do cliente-12
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-10
#   └─ [Thread-12] Concluído em 35.7826s
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#   └─ [Thread-10] Concluído em 38.6617s
#
# [Consumer] Processando a request do cliente-13
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
#   └─ [Thread-13] Concluído em 40.4837s
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-15
#   └─ [Thread-14] Concluído em 42.3143s
#   └─ [Thread-15] Concluído em 44.6115s
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-16
# [Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
#   └─ [Thread-16] Concluído em 46.7143s
# [Consumer] Processando a request do cliente-17
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-18
#   └─ [Thread-17] Concluído em 49.5877s
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-21
#   └─ [Thread-18] Concluído em 51.9054s
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
#   └─ [Thread-21] Concluído em 54.4289s
# [Consumer] Processando a request do cliente-19
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-22
#   └─ [Thread-19] Concluído em 56.3732s
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
#   └─ [Thread-22] Concluído em 58.194s
# [Consumer] Processando a request do cliente-23
#   └─ [Thread-23] Concluído em 60.0697s
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-20
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-24
#   └─ [Thread-20] Concluído em 62.4148s
#   └─ [Thread-24] Concluído em 64.1466s
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-25
# [Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
#   └─ [Thread-25] Concluído em 66.397s
# [Consumer] Processando a request do cliente-27
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-28
#   └─ [Thread-27] Concluído em 67.7965s
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
#   └─ [Thread-28] Concluído em 69.4258s
# [Consumer] Processando a request do cliente-26
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-29
#   └─ [Thread-26] Concluído em 71.6603s
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
#   └─ [Thread-29] Concluído em 73.3703s
#  [CHECK] Bateria do Prompt 4 finalizada com sucesso.
#
#
# ============================================================
#  [PROMPT 5/8] Iniciando bateria de 30 testes paralelos...
#  Conteúdo: The history of the internet began in the 1960s wit...
# ============================================================
# [Consumer] Processando a request do cliente-0
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-1
#   └─ [Thread-0] Concluído em 3.5042s
#   └─ [Thread-1] Concluído em 6.6212s[Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
#
# [Consumer] Processando a request do cliente-2
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#
#   └─ [Thread-2] Concluído em 9.3434s
# [Consumer] Processando a request do cliente-4
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-3
#   └─ [Thread-4] Concluído em 11.5982s
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
#   └─ [Thread-3] Concluído em 14.1628s
# [Consumer] Processando a request do cliente-5
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-6
#   └─ [Thread-5] Concluído em 17.1004s
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
#   └─ [Thread-6] Concluído em 20.129s
# [Consumer] Processando a request do cliente-7
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#
#   └─ [Thread-7] Concluído em 24.2854s
# [Consumer] Processando a request do cliente-8
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
#   └─ [Thread-8] Concluído em 26.4506s
# [Consumer] Processando a request do cliente-9
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#
#   └─ [Thread-9] Concluído em 28.4985s
# [Consumer] Processando a request do cliente-10
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-11
#   └─ [Thread-10] Concluído em 31.5771s
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-12
#   └─ [Thread-11] Concluído em 34.7627s
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
#   └─ [Thread-12] Concluído em 37.2012s
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-13
#   └─ [Thread-14] Concluído em 39.1922s
#   └─ [Thread-13] Concluído em 41.5393s
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-15
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-16
#   └─ [Thread-15] Concluído em 43.5689s
# [Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
#   └─ [Thread-16] Concluído em 45.9698s
# [Consumer] Processando a request do cliente-18
#   └─ [Thread-18] Concluído em 49.0085s
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-17
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
#   └─ [Thread-17] Concluído em 51.6121s
# [Consumer] Processando a request do cliente-20
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-19
#   └─ [Thread-20] Concluído em 53.355s
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
#   └─ [Thread-19] Concluído em 55.5072s
# [Consumer] Processando a request do cliente-21
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-22
#   └─ [Thread-21] Concluído em 57.1127s
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-23
#   └─ [Thread-22] Concluído em 59.074s
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#
#   └─ [Thread-23] Concluído em 61.1391s
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-26
#   └─ [Thread-24] Concluído em 63.2346s
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
#   └─ [Thread-26] Concluído em 64.9571s
# [Consumer] Processando a request do cliente-25
# [Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-27
#   └─ [Thread-25] Concluído em 66.9455s
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-28
#   └─ [Thread-27] Concluído em 68.5531s
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#   └─ [Thread-28] Concluído em 70.2603s
#
# [Consumer] Processando a request do cliente-29
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
#   └─ [Thread-29] Concluído em 71.5696s
#  [CHECK] Bateria do Prompt 5 finalizada com sucesso.
#
#
# ============================================================
#  [PROMPT 6/8] Iniciando bateria de 30 testes paralelos...
#  Conteúdo: Coffee is one of the most consumed beverages in th...
# ============================================================
# [Consumer] Processando a request do cliente-0
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-1
#   └─ [Thread-0] Concluído em 2.1626s
# [Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
#   └─ [Thread-1] Concluído em 4.7019s
# [Consumer] Processando a request do cliente-3
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-4
#   └─ [Thread-3] Concluído em 7.2733s
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-2
#   └─ [Thread-4] Concluído em 8.8865s
#   └─ [Thread-2] Concluído em 10.5971s
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-5
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
#   └─ [Thread-5] Concluído em 12.0643s
# [Consumer] Processando a request do cliente-7
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#
#   └─ [Thread-7] Concluído em 14.0527s
# [Consumer] Processando a request do cliente-6
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-8
#   └─ [Thread-6] Concluído em 17.0294s
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-9
#   └─ [Thread-8] Concluído em 19.8547s
#   └─ [Thread-9] Concluído em 22.0207s
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-10
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
#   └─ [Thread-10] Concluído em 23.6423s
# [Consumer] Processando a request do cliente-11
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-13
#   └─ [Thread-11] Concluído em 25.2284s
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
#   └─ [Thread-13] Concluído em 26.5844s
# [Consumer] Processando a request do cliente-12
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
#   └─ [Thread-12] Concluído em 28.3824s
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-17
#   └─ [Thread-14] Concluído em 31.1604s
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-15
#   └─ [Thread-17] Concluído em 33.1694s
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-18
#   └─ [Thread-15] Concluído em 35.6656s
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#
#   └─ [Thread-18] Concluído em 37.5857s
# [Consumer] Processando a request do cliente-16
# [Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
#   └─ [Thread-16] Concluído em 39.2448s
# [Consumer] Processando a request do cliente-20
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-19
#   └─ [Thread-20] Concluído em 40.3277s
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
#   └─ [Thread-19] Concluído em 42.4413s
# [Consumer] Processando a request do cliente-21
#   └─ [Thread-21] Concluído em 44.1955s
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-22
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
#   └─ [Thread-22] Concluído em 45.775s
# [Consumer] Processando a request do cliente-23
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-25
#   └─ [Thread-23] Concluído em 47.4041s
#   └─ [Thread-25] Concluído em 48.8494s
# [Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
#   └─ [Thread-24] Concluído em 50.94s
# [Consumer] Processando a request do cliente-26
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
#   └─ [Thread-26] Concluído em 52.2825s
# [Consumer] Processando a request do cliente-27
#   └─ [Thread-27] Concluído em 53.6241s
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-28
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-29
#   └─ [Thread-28] Concluído em 54.9034s
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
#   └─ [Thread-29] Concluído em 55.6194s
#  [CHECK] Bateria do Prompt 6 finalizada com sucesso.
#
#
# ============================================================
#  [PROMPT 7/8] Iniciando bateria de 30 testes paralelos...
#  Conteúdo: The Olympic Games are more than just a sporting ev...
# ============================================================
# [Consumer] Processando a request do cliente-0
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-1
#   └─ [Thread-0] Concluído em 2.4005s
#   └─ [Thread-1] Concluído em 5.5005s
# [Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-2
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-3
#   └─ [Thread-2] Concluído em 7.7711s
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-5
#   └─ [Thread-3] Concluído em 10.1133s
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
#   └─ [Thread-5] Concluído em 11.8667s
# [Consumer] Processando a request do cliente-4
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-8
#   └─ [Thread-4] Concluído em 14.7035s
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
#   └─ [Thread-8] Concluído em 17.9623s
# [Consumer] Processando a request do cliente-6
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-9
#   └─ [Thread-6] Concluído em 21.2457s
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#
#   └─ [Thread-9] Concluído em 23.5665s
# [Consumer] Processando a request do cliente-10
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-7
#   └─ [Thread-10] Concluído em 25.335s
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#
#   └─ [Thread-7] Concluído em 27.1145s
# [Consumer] Processando a request do cliente-11
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
#   └─ [Thread-11] Concluído em 29.1494s
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-13
#   └─ [Thread-14] Concluído em 31.6776s
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
#   └─ [Thread-13] Concluído em 35.0747s
# [Consumer] Processando a request do cliente-12
#   └─ [Thread-12] Concluído em 38.1182s
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-15
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-16
#   └─ [Thread-15] Concluído em 40.4623s
# [Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-17
#   └─ [Thread-16] Concluído em 42.4129s
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
#   └─ [Thread-17] Concluído em 44.8017s
# [Consumer] Processando a request do cliente-19
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
#   └─ [Thread-19] Concluído em 46.9633s
# [Consumer] Processando a request do cliente-18
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-21
#   └─ [Thread-18] Concluído em 49.7109s
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
#   └─ [Thread-21] Concluído em 51.8401s
# [Consumer] Processando a request do cliente-22
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
#   └─ [Thread-22] Concluído em 54.2948s
# [Consumer] Processando a request do cliente-20
#   └─ [Thread-20] Concluído em 56.322s
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
#   └─ [Thread-24] Concluído em 57.5957s
# [Consumer] Processando a request do cliente-23
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#   └─ [Thread-23] Concluído em 59.8352s
#
# [Consumer] Processando a request do cliente-26
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
#   └─ [Thread-26] Concluído em 61.9972s
# [Consumer] Processando a request do cliente-25
# [Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#   └─ [Thread-25] Concluído em 63.9275s
#
# [Consumer] Processando a request do cliente-28
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-27
#   └─ [Thread-28] Concluído em 64.8828s
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
#   └─ [Thread-27] Concluído em 67.4889s
# [Consumer] Processando a request do cliente-29
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
#   └─ [Thread-29] Concluído em 68.3971s
#  [CHECK] Bateria do Prompt 7 finalizada com sucesso.
#
#
# ============================================================
#  [PROMPT 8/8] Iniciando bateria de 30 testes paralelos...
#  Conteúdo: The Renaissance was a period of profound cultural,...
# ============================================================
# [Consumer] Processando a request do cliente-0
#   └─ [Thread-0] Concluído em 2.4735s[Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
#
# [Consumer] Processando a request do cliente-1
#   └─ [Thread-1] Concluído em 6.1663s
# [Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-2
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#   └─ [Thread-2] Concluído em 10.3352s
#
# [Consumer] Processando a request do cliente-3
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-4
#   └─ [Thread-3] Concluído em 15.1005s
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
#   └─ [Thread-4] Concluído em 17.6785s
# [Consumer] Processando a request do cliente-5
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-6
#   └─ [Thread-5] Concluído em 20.5791s
#   └─ [Thread-6] Concluído em 23.9792s
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-8
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
#   └─ [Thread-8] Concluído em 27.0706s
# [Consumer] Processando a request do cliente-7
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-9
#   └─ [Thread-7] Concluído em 29.9326s
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-10
#   └─ [Thread-9] Concluído em 32.3642s
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-11
#   └─ [Thread-10] Concluído em 35.5163s
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#   └─ [Thread-11] Concluído em 38.9229s
#
# [Consumer] Processando a request do cliente-12
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
#   └─ [Thread-12] Concluído em 42.7087s
# [Consumer] Processando a request do cliente-13
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
#   └─ [Thread-13] Concluído em 45.6188s
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-15
#   └─ [Thread-14] Concluído em 47.735s
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
#   └─ [Thread-15] Concluído em 50.1546s
# [Consumer] Processando a request do cliente-16
# [Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-17
#   └─ [Thread-16] Concluído em 53.7113s
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
#   └─ [Thread-17] Concluído em 56.3521s
# [Consumer] Processando a request do cliente-18
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#   └─ [Thread-18] Concluído em 59.2537s
#
# [Consumer] Processando a request do cliente-20
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
#   └─ [Thread-20] Concluído em 61.7391s
# [Consumer] Processando a request do cliente-21
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-19
#   └─ [Thread-21] Concluído em 64.1385s
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#   └─ [Thread-19] Concluído em 66.7302s
#
# [Consumer] Processando a request do cliente-22
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-23
#   └─ [Thread-22] Concluído em 69.0264s
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#
#   └─ [Thread-23] Concluído em 71.5709s
# [Consumer] Processando a request do cliente-25
# [Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
#   └─ [Thread-25] Concluído em 74.4919s
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-26
#   └─ [Thread-24] Concluído em 76.6636s
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-27
#   └─ [Thread-26] Concluído em 78.5743s
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#   └─ [Thread-27] Concluído em 81.0175s
#
# [Consumer] Processando a request do cliente-28
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-29
#   └─ [Thread-28] Concluído em 83.1187s
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
#   └─ [Thread-29] Concluído em 85.3766s
#  [CHECK] Bateria do Prompt 8 finalizada com sucesso.
#
#
# [SYSTEM] Dados brutos de performance do modelo google_pegasus_xsum salvos em: ./raw/raw_data_requests_google_pegasus_xsum.csv
#
# ############################################################
#  [FINALIZADO] Todos os testes foram concluídos e salvos.
# ############################################################

# %%
# from google.colab import data_table
import pandas as pd
import numpy as np
import statistics

df = pd.read_csv(f"./raw/raw_data_requests_{MODEL}.csv")
display(df)
# Out:
#      prompt_id  req_id                                     prompt_entrada  \
# 0            1       2  Solar energy is one of the most promising rene...
# 1            1       1  Solar energy is one of the most promising rene...
# 2            1       0  Solar energy is one of the most promising rene...
# 3            1       4  Solar energy is one of the most promising rene...
# 4            1       3  Solar energy is one of the most promising rene...
# ..         ...     ...                                                ...
# 235          8      24  The Renaissance was a period of profound cultu...
# 236          8      26  The Renaissance was a period of profound cultu...
# 237          8      27  The Renaissance was a period of profound cultu...
# 238          8      28  The Renaissance was a period of profound cultu...
# 239          8      29  The Renaissance was a period of profound cultu...
#
#                                         saida_resposta  tokens_in  tokens_out  \
# 0    Brazil is one of the world’s largest producers...        140          15
# 1    Brazil is one of the world’s largest producers...        140          15
# 2    Brazil is one of the world’s largest producers...        140          15
# 3    Brazil is one of the world’s largest producers...        140          15
# 4    Brazil is one of the world’s largest producers...        140          15
# ..                                                 ...        ...         ...
# 235  The Renaissance was a period of profound cultu...         92          26
# 236  The Renaissance was a period of profound cultu...         92          26
# 237  The Renaissance was a period of profound cultu...         92          26
# 238  The Renaissance was a period of profound cultu...         92          26
# 239  The Renaissance was a period of profound cultu...         92          26
#
#      custo_usd   tempo_s
# 0     0.000093  100.4711
# 1     0.000093  103.3176
# 2     0.000093  105.9512
# 3     0.000093  110.1403
# 4     0.000093  114.0165
# ..         ...       ...
# 235   0.000071   76.6636
# 236   0.000071   78.5743
# 237   0.000071   81.0175
# 238   0.000071   83.1187
# 239   0.000071   85.3766
#
# [240 rows x 8 columns]

# %%
# Fazendo análise e registrando dados ==========================
import statistics, csv, os
import numpy as np

# Mantendo seus caminhos e nomes de variáveis
CSV_RAW = f"./raw/raw_data_requests_{MODEL}.csv" # Ajustado para bater com a pasta 'tempos' do bloco anterior
METRICS_FOLDER = "./metrics"
CSV_REQ_TIMES_METRICS = f"{METRICS_FOLDER}/metrics_data_requests_{MODEL}.csv"

TIMES_REQ_PER_PROMPT_ALL = {}

os.makedirs(METRICS_FOLDER, exist_ok=True)

with open(CSV_RAW, mode="r", newline="", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    for row in reader:
        pid = int(row["prompt_id"])
        time = float(row["tempo_s"])
        # Agora capturamos tokens e custo unitário
        t_in = int(row["tokens_in"])
        c_usd = float(row["custo_usd"])

        if pid not in TIMES_REQ_PER_PROMPT_ALL:
            TIMES_REQ_PER_PROMPT_ALL[pid] = {
                "tempos": [],
                "tokens_input": t_in,
                "custos": []
            }
        TIMES_REQ_PER_PROMPT_ALL[pid]["tempos"].append(time)
        TIMES_REQ_PER_PROMPT_ALL[pid]["custos"].append(c_usd)

with open(CSV_REQ_TIMES_METRICS, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    # Cabeçalho atualizado para suportar os gráficos de Throughput e Custo
    writer.writerow([
        "prompt_id",
        "tokens_input",
        "tempo_req_min_s",
        "tempo_req_max_s",
        "tempo_total_s",
        "throughput_req_s",
        "req_por_prompt",
        "media_tempo_s",
        "desvio_padrao_s",
        "coef_var_%",
        "custo_medio_usd",
        "custo_total_usd",
        "p95_s",
        "p99_s"
    ])

    for pid, data in TIMES_REQ_PER_PROMPT_ALL.items():
        times = data["tempos"]
        costs = data["custos"]
        tokens_input = data["tokens_input"]

        min_time = min(times)
        max_time = max(times)
        total_time = round(sum(times), 4)
        req_per_prompt = len(times)

        # Cálculos de tempo
        avg = round(statistics.mean(times), 4)
        std = round(statistics.pstdev(times), 4)

        # Coeficiente de Variação em % (padrão acadêmico)
        coef_var = round((std / avg) * 100, 2)

        # Cálculo de Throughput (Requisições por segundo)
        throughput = round(req_per_prompt / total_time, 2)

        # Cálculos Financeiros
        avg_cost = round(statistics.mean(costs), 6)
        total_cost = round(sum(costs), 6)

        p95 = round(float(np.percentile(times, 95)), 4)
        p99 = round(float(np.percentile(times, 99)), 4)

        writer.writerow([
            pid,
            tokens_input,
            min_time,
            max_time,
            total_time,
            throughput,
            req_per_prompt,
            avg,
            std,
            coef_var,
            avg_cost,
            total_cost,
            p95,
            p99
        ])

print("Análise e cálculo de métricas finalizado")
# Out:
# Análise e cálculo de métricas finalizado

# %%
# Juntando o csv de output de métricas de cada modelo ========================
import pandas as pd
import glob
import os

path = "./metrics"
all_files = glob.glob(os.path.join(path, "*.csv"))
print(all_files, type(all_files[0]))

dfs = []
for file in all_files:
  df = pd.read_csv(file)
  model_name = os.path.splitext(os.path.basename(file))[0].replace("metrics_data_requests_", "")

  df["modelo"] = model_name
  dfs.append(df)

final_df = pd.concat(dfs, ignore_index=True)
final_df.to_csv("models_metrics_data_requests.csv", index=False)
print(".csv de métricas dos modelos armazenadas em csv")
# Out:
# ['./metrics/metrics_data_requests_facebook_bart_large_cnn.csv', './metrics/metrics_data_requests_google_pegasus_xsum.csv', './metrics/metrics_data_requests_knkarthick_MEETING_SUMMARY.csv', './metrics/metrics_data_requests_google_pegasus_cnn_dailymail.csv'] <class 'str'>
# .csv de métricas dos modelos armazenadas em csv

# %%
# Visualização gráfica dos resultados consolidados ========================
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Carregar o CSV consolidado com as métricas de todos os modelos
CSV_FINAL = "models_metrics_data_requests.csv"

try:
    df = pd.read_csv(CSV_FINAL)
    print(f"\033[92m[SUCCESS]\033[0m Dados carregados: {df['modelo'].unique().tolist()}")
except FileNotFoundError:
    print(f"\033[91m[ERROR]\033[0m Arquivo {CSV_FINAL} não encontrado.")

# Configuração global de estilo
sns.set_theme(style="whitegrid", palette="muted")

# Vazão Média (Throughput) por Modelo
plt.figure(figsize=(10, 6))
df_sorted_tp = df.groupby("modelo")["throughput_req_s"].mean().sort_values(ascending=False).reset_index()
sns.barplot(data=df_sorted_tp, x="modelo", y="throughput_req_s", hue="modelo", palette="viridis", legend=False)
plt.xticks(rotation=45)
plt.title("Capacidade de Processamento (Vazão) por Modelo", fontsize=13)
plt.ylabel("Throughput (Req/s)")
plt.xlabel("Arquitetura do Modelo")
plt.tight_layout()
plt.show()

# Distribuição de Latência (Média de Tempo)
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="modelo", y="media_tempo_s", hue="modelo", palette="Set2", legend=False)
plt.xticks(rotation=45)
plt.title("Distribuição das Médias de Latência por Modelo", fontsize=13)
plt.ylabel("Tempo Médio (s)")
plt.xlabel("Arquitetura do Modelo")
plt.tight_layout()
plt.show()

# Percentis de Latência (p95 e p99)
plt.figure(figsize=(10, 6))
df_p = df.groupby("modelo")[["p95_s", "p99_s"]].mean().reset_index()
df_melted_p = df_p.melt(id_vars=["modelo"], value_vars=["p95_s", "p99_s"], var_name="Métrica", value_name="Tempo (s)")
sns.lineplot(data=df_melted_p, x="modelo", y="Tempo (s)", hue="Métrica", marker="o", markersize=8)
plt.xticks(rotation=45)
plt.title("Análise de Cauda Longa: Médias de P95 e P99", fontsize=13)
plt.ylabel("Tempo (s)")
plt.xlabel("Arquitetura do Modelo")
plt.tight_layout()
plt.show()

# Coeficiente de Variação (Estabilidade)
plt.figure(figsize=(10, 6))
df_cv = df.groupby("modelo")["coef_var_%"].mean().sort_values().reset_index()
sns.barplot(data=df_cv, x="modelo", y="coef_var_%", hue="modelo", palette="magma", legend=False)
plt.xticks(rotation=45)
plt.title("Instabilidade de Resposta: Coeficiente de Variação (%)", fontsize=13)
plt.ylabel("CV (%)")
plt.xlabel("Arquitetura do Modelo")
plt.tight_layout()
plt.show()

# Eficiência Econômica (Custo por 1k Tokens)
plt.figure(figsize=(10, 6))
# Cálculo normalizado para o gráfico
df["cost_per_1k_tokens"] = df["custo_medio_usd"] / (df["tokens_input"] / 1000)
df_cost = df.groupby("modelo")["cost_per_1k_tokens"].mean().sort_values().reset_index()
ax5 = sns.barplot(data=df_cost, x="modelo", y="cost_per_1k_tokens", hue="modelo", palette="rocket", legend=False)
plt.xticks(rotation=45)
plt.title("Eficiência Econômica Normalizada (USD / 1k Tokens)", fontsize=13)
plt.ylabel("Custo Projetado (USD)")
plt.xlabel("Arquitetura do Modelo")
ax5.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.5f')) # Formatação para microcentavos
plt.tight_layout()
plt.show()

print("\033[92m[DONE]\033[0m Geração de gráficos finalizada.")
# Out:
# [SUCCESS] Dados carregados: ['facebook_bart_large_cnn', 'google_pegasus_xsum', 'knkarthick_MEETING_SUMMARY', 'google_pegasus_cnn_dailymail']
# [DONE] Geração de gráficos finalizada.

# %%
# Comparativo de modelos
import pandas as pd

# Carregar o arquivo original de métricas
INPUT_CSV = "models_metrics_data_requests.csv"
OUTPUT_CSV = "comp_final_models.csv"

try:
    df = pd.read_csv(INPUT_CSV)

    # Agrupar por modelo e calcular a média real de todos os testes
    # Isso elimina qualquer "estipulação" e usa apenas os dados brutos
    comparativo = df.groupby("modelo").agg({
        "media_tempo_s": "mean",
        "tokens_input": "mean",
        "throughput_req_s": "mean",
        "coef_var_%": "mean",
        "p99_s": "mean",
        "p95_s": "mean",
        "custo_medio_usd": "mean",
        "custo_total_usd": "sum",
        "tempo_req_min_s": "min",
        "tempo_req_max_s": "max",
        "tempo_total_s": "sum"
    }).reset_index()

    # Arredondamento para o padrão da Tabela do Relatório
    comparativo = comparativo.round({
        "media_tempo_s": 4,
        "tokens_input": 0,
        "throughput_req_s": 4,
        "coef_var_%": 4,
        "p99_s": 4,
        "p95_s": 4,
        "custo_medio_usd": 6,
        "custo_total_usd": 6,
        "tempo_req_min_s": 4,
        "tempo_req_max_s": 4,
        "tempo_total_s": 4
    })

    # Salvar o CSV final
    comparativo.to_csv(OUTPUT_CSV, index=False)

    print("\033[92m[SUCESSO]\033[0m CSV comp_final_models.csv comparativo dos modelos.")
    print(comparativo)

except FileNotFoundError:
    print("\033[91m[ERRO]\033[0m Certifique-se de que o arquivo 'models_metrics_data_requests.csv' está na mesma pasta.")
# Out:
# [SUCESSO] CSV comp_final_models.csv comparativo dos modelos.
#                          modelo  media_tempo_s  tokens_input  \
# 0       facebook_bart_large_cnn        39.6182         112.0
# 1  google_pegasus_cnn_dailymail        51.2190         107.0
# 2           google_pegasus_xsum        54.0618         107.0
# 3    knkarthick_MEETING_SUMMARY        22.6142         112.0
#
#    throughput_req_s  coef_var_%    p99_s    p95_s  custo_medio_usd  \
# 0            0.0250     52.5550  71.0145  68.9479         0.000107
# 1            0.0213     54.1325  95.6612  92.2502         0.000095
# 2            0.0225     46.8237  86.1013  84.0662         0.000079
# 3            0.0512     49.1162  39.6723  38.2196         0.000088
#
#    custo_total_usd  tempo_req_min_s  tempo_req_max_s  tempo_total_s
# 0          0.02574           1.9327          75.0208      9508.3629
# 1          0.02283           2.4627         114.6787     12292.5655
# 2          0.01890           2.1626         168.9324     12974.8417
# 3          0.02121           1.2787          69.6454      5427.4008

# %%
# !sudo rabbitmqctl stop_app
# !sudo rabbitmqctl reset
# !sudo rabbitmqctl start_app
# Out:
# ERROR:pika.adapters.blocking_connection:Unexpected connection close detected: ConnectionClosedByBroker: (320) "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'"
# Exception in thread Thread-3 (consumer):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipython-input-1876121000.py", line 40, in consumer
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 1883, in start_consuming
#     self._process_data_events(time_limit=None)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 2044, in _process_data_events
#     self.connection.process_data_events(time_limit=time_limit)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 842, in process_data_events
#     self._flush_output(common_terminator)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 523, in _flush_output
#     raise self._closed_result.value.error
# pika.exceptions.ConnectionClosedByBroker: (320, "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'")
# Stopping rabbit application on node rabbit@d9fed56b4ec2 ...
# Resetting node rabbit@d9fed56b4ec2 ...
#
# 02:49:06.099 [warn]  Feature flags: the previous instance of this node must have failed to write the `feature_flags` file at `/var/lib/rabbitmq/mnesia/rabbit@d9fed56b4ec2-feature_flags`:
#
# 02:49:06.099 [warn]  Feature flags:   - list of previously enabled feature flags now marked as such: [:maintenance_mode_status]
# Starting node rabbit@d9fed56b4ec2 ...

# %%
# !sudo rabbitmqctl delete_queue summarize_queue
# Out:
# Deleting queue 'summarize_queue' on vhost '/' ...
# Error:
# Queue not found
