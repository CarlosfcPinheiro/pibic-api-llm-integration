# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosfcPinheiro/pibic-api-llm-integration/blob/main/pibic_queue_rabbitmq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Teste de requisições para LLMs utilizando padrão de Filas assíncronas
# O objetivo principal é testar e avaliar o tempo de resposta de requisições para uma API que interaja com LLMs, utilizando o padrão de filas assíncronas.
#
# ## Código e estrutura
# Para análise, são utilizados **8 prompts diferentes**, que buscam explorar diferentes tamanhos e temáticas de texto. Nesse script de teste, cada cliente/producer é responsável por enviar um prompt (uma request) para a fila de requests `request_summarize_queue`, sendo **30 clientes/producers** para cada prompt, onde são armazenado os tempos de resposta de todas as requests para cada prompt, respectivamente.
#
# O arquivo .csv que contém os dados de tempo da request é lido posteriormente para compor os dados de análise, que também são escritos em um outro csv.
#
# Além disso, cada conjunto de testes são executados utilizando **4 modelos diferentes**, que fundamentalmente são especializados em sumarização, mas com objetivos diferentes. Os modelos utilizados são:
#
# - facebook/bart_large_cnn
# - google/pegasus_cnn_dailymail
# - knkarthick/MEETING_SUMMARY
# - google/pegasus_xsum
#
# O worker/consumer é o responsável por receber as mensagens (corpo das requests) da fila `request_summarize_queue`, processar, realizar a request para a API gateway de LLM, e devolver a resposta para o cliente, publicando a resposta em sua fila de respostas exclusiva.
#
# ## Padrões e bibliotecas
# O padrão a ser utilizado é o de **Filas assíncronas**, dado que utiliza uma fila de mensagens (request_summarize_queue) com diferentes clientes/producers atuando em **threads únicas**.
#
# As principais bibliotecas utilizadas são:
# - time (funções de manipulação de tempo)
# - requests (envio de requisições HTTP)
# - csv (manipulação de arquivos csv)
# - statistics (funções para cálculos estatísticos)
# - numpy (funções para manipulação de arrays e matrizes)
# - pika (SDK python do RabbitMQ)
# - threading (gerenciamento de threads)
#
# ## Métricas analisadas
# As métricas utilizadas para análise do tempo de resposta da requisição para cada prompt foram as seguintes:
# - Média de tempo (tempo médio de resposta das requisições)
# - Máximo e Mínimo (tempo com valores máximos e mínimos)
# - Desvio padrão (dispersão absoluta dos dados em relação à média, numericamente)
# - Coeficiente de variação (dispersão relativa dos dados em relação à média, em  porcentagem)
# - Percentil - 95% e 99% (valores abaixo do qual uma certa porcentagem dos tempos se encontram)
#
# > Todas as métricas levam em consideração a unidade de segundos para o tempo de resposta da requisição

# %%
# !apt-get update
# !apt-get install rabbitmq-server -y
# !service rabbitmq-server start
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,633 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,860 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,572 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,598 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,966 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Fetched 34.8 MB in 3s (10.1 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   erlang-asn1 erlang-base erlang-crypto erlang-eldap erlang-ftp erlang-inets
#   erlang-mnesia erlang-os-mon erlang-parsetools erlang-public-key
#   erlang-runtime-tools erlang-snmp erlang-ssl erlang-syntax-tools erlang-tftp
#   erlang-tools erlang-xmerl libsctp1 logrotate
# Suggested packages:
#   erlang erlang-manpages erlang-doc lksctp-tools bsd-mailx | mailx
# The following NEW packages will be installed:
#   erlang-asn1 erlang-base erlang-crypto erlang-eldap erlang-ftp erlang-inets
#   erlang-mnesia erlang-os-mon erlang-parsetools erlang-public-key
#   erlang-runtime-tools erlang-snmp erlang-ssl erlang-syntax-tools erlang-tftp
#   erlang-tools erlang-xmerl libsctp1 logrotate rabbitmq-server
# 0 upgraded, 20 newly installed, 0 to remove and 6 not upgraded.
# Need to get 35.1 MB of archives.
# After this operation, 55.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 logrotate amd64 3.19.0-1ubuntu1.1 [54.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-base amd64 1:24.2.1+dfsg-1ubuntu0.6 [9,830 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-asn1 amd64 1:24.2.1+dfsg-1ubuntu0.6 [911 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-crypto amd64 1:24.2.1+dfsg-1ubuntu0.6 [157 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-public-key amd64 1:24.2.1+dfsg-1ubuntu0.6 [784 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-mnesia amd64 1:24.2.1+dfsg-1ubuntu0.6 [891 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-runtime-tools amd64 1:24.2.1+dfsg-1ubuntu0.6 [227 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-ssl amd64 1:24.2.1+dfsg-1ubuntu0.6 [1,584 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-eldap amd64 1:24.2.1+dfsg-1ubuntu0.6 [125 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-ftp amd64 1:24.2.1+dfsg-1ubuntu0.6 [84.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-tftp amd64 1:24.2.1+dfsg-1ubuntu0.6 [103 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-inets amd64 1:24.2.1+dfsg-1ubuntu0.6 [627 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-snmp amd64 1:24.2.1+dfsg-1ubuntu0.6 [1,895 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-os-mon amd64 1:24.2.1+dfsg-1ubuntu0.6 [91.1 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-parsetools amd64 1:24.2.1+dfsg-1ubuntu0.6 [194 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-syntax-tools amd64 1:24.2.1+dfsg-1ubuntu0.6 [303 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-tools amd64 1:24.2.1+dfsg-1ubuntu0.6 [635 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 erlang-xmerl amd64 1:24.2.1+dfsg-1ubuntu0.6 [1,383 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsctp1 amd64 1.0.19+dfsg-1build1 [9,370 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 rabbitmq-server all 3.9.27-0ubuntu0.2 [15.2 MB]
# Fetched 35.1 MB in 1s (36.9 MB/s)
# Selecting previously unselected package logrotate.
# (Reading database ... 117528 files and directories currently installed.)
# Preparing to unpack .../00-logrotate_3.19.0-1ubuntu1.1_amd64.deb ...
# Unpacking logrotate (3.19.0-1ubuntu1.1) ...
# Selecting previously unselected package erlang-base.
# Preparing to unpack .../01-erlang-base_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-base (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-asn1.
# Preparing to unpack .../02-erlang-asn1_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-asn1 (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-crypto.
# Preparing to unpack .../03-erlang-crypto_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-crypto (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-public-key.
# Preparing to unpack .../04-erlang-public-key_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-public-key (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-mnesia.
# Preparing to unpack .../05-erlang-mnesia_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-mnesia (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-runtime-tools.
# Preparing to unpack .../06-erlang-runtime-tools_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-runtime-tools (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-ssl.
# Preparing to unpack .../07-erlang-ssl_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-ssl (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-eldap.
# Preparing to unpack .../08-erlang-eldap_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-eldap (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-ftp.
# Preparing to unpack .../09-erlang-ftp_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-ftp (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-tftp.
# Preparing to unpack .../10-erlang-tftp_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-tftp (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-inets.
# Preparing to unpack .../11-erlang-inets_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-inets (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-snmp.
# Preparing to unpack .../12-erlang-snmp_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-snmp (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-os-mon.
# Preparing to unpack .../13-erlang-os-mon_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-os-mon (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-parsetools.
# Preparing to unpack .../14-erlang-parsetools_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-parsetools (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-syntax-tools.
# Preparing to unpack .../15-erlang-syntax-tools_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-syntax-tools (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-tools.
# Preparing to unpack .../16-erlang-tools_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-tools (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package erlang-xmerl.
# Preparing to unpack .../17-erlang-xmerl_1%3a24.2.1+dfsg-1ubuntu0.6_amd64.deb ...
# Unpacking erlang-xmerl (1:24.2.1+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package libsctp1:amd64.
# Preparing to unpack .../18-libsctp1_1.0.19+dfsg-1build1_amd64.deb ...
# Unpacking libsctp1:amd64 (1.0.19+dfsg-1build1) ...
# Selecting previously unselected package rabbitmq-server.
# Preparing to unpack .../19-rabbitmq-server_3.9.27-0ubuntu0.2_all.deb ...
# Unpacking rabbitmq-server (3.9.27-0ubuntu0.2) ...
# Setting up logrotate (3.19.0-1ubuntu1.1) ...
# Created symlink /etc/systemd/system/timers.target.wants/logrotate.timer → /lib/systemd/system/logrotate.timer.
# Setting up erlang-base (1:24.2.1+dfsg-1ubuntu0.6) ...
# Searching for services which depend on erlang and should be started... none found.
# Setting up erlang-xmerl (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-syntax-tools (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-parsetools (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-asn1 (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-tftp (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up libsctp1:amd64 (1.0.19+dfsg-1build1) ...
# Setting up erlang-mnesia (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-crypto (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-runtime-tools (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-tools (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-snmp (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-public-key (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-ssl (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-os-mon (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-eldap (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-ftp (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up erlang-inets (1:24.2.1+dfsg-1ubuntu0.6) ...
# Setting up rabbitmq-server (3.9.27-0ubuntu0.2) ...
# Adding group `rabbitmq' (GID 108) ...
# Done.
# Adding system user `rabbitmq' (UID 105) ...
# Adding new user `rabbitmq' (UID 105) with group `rabbitmq' ...
# Not creating home directory `/var/lib/rabbitmq'.
# Created symlink /etc/systemd/system/multi-user.target.wants/rabbitmq-server.service → /lib/systemd/system/rabbitmq-server.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
#  * Starting RabbitMQ Messaging Server rabbitmq-server
#    ...done.

# %%
# !sudo rabbitmqctl list_queues
# Out:
# Timeout: 60.0 seconds ...
# Listing queues for vhost / ...

# %%
pip install pika --upgrade
# Out:
# Collecting pika
#   Downloading pika-1.3.2-py3-none-any.whl.metadata (13 kB)
# Downloading pika-1.3.2-py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: pika
# Successfully installed pika-1.3.2

# %%
# Definição dos prompts de teste ==========================
PROMPTS = [
    """Solar energy is one of the most promising renewable sources for the planet’s future. With concerns about climate change and the need to reduce fossil fuel dependence, many countries are investing in clean technologies. Brazil has one of the largest solar potentials, especially in the Northeast and Midwest, where radiation is high year-round. The installation of solar panels in homes and businesses has grown, driven by incentives and lower equipment costs. Distributed generation allows consumers to also produce energy, helping decentralize the electricity system. Challenges remain, such as infrastructure, storage, and stronger public policies, but with technology and social engagement, solar energy is set to play an increasingly important role in Brazil’s energy matrix.""",

    """The city of Ouro Preto, located in the state of Minas Gerais, is one of the greatest symbols of Brazilian colonial architecture and history. Founded in the 17th century during the gold rush, it quickly became one of the main economic centers of the Portuguese colony, attracting thousands of people in search of wealth. Its stone streets, steep slopes, and preserved buildings reveal a past marked by opulence, religiosity, and resistance. Ouro Preto is home to some of the most impressive baroque churches in Brazil, such as the Church of Saint Francis of Assisi, designed by Aleijadinho and decorated with works by Mestre Ataíde. The city was also the stage for important events of the Inconfidência Mineira, a movement that sought Brazil’s independence from Portugal. Today, the city is recognized as a UNESCO World Heritage Site, attracting tourists interested in history, art, and culture. In addition to its historical value, Ouro Preto has a vibrant university life thanks to the Federal University of Ouro Preto (UFOP) and hosts various festivals of art, music, and cinema throughout the year. This combination of tradition and youth makes the city a unique place where past and present coexist in harmony.""",

    """Artificial intelligence (AI) is one of the most transformative technologies of the 21st century. It impacts medicine, education, industry, and commerce, improving efficiency and user experience. At the same time, AI raises ethical concerns about data use, bias, and its impact on jobs. Governments and society must ensure its benefits are distributed fairly and responsibly.""",

    """Classical music, although it emerged centuries ago, continues to influence contemporary composers. Works by Beethoven, Mozart, and Bach are studied in conservatories and reinterpreted in different musical styles. This tradition shows how art can transcend generations and reinvent itself.""",

    """The history of the internet began in the 1960s with military projects in the United States, evolving into academic networks and later into commercial use. Today, the internet connects billions of people in real time, transforming the way we work, study, and interact. Digital platforms enable instant communication, e-commerce, and unlimited access to information. However, problems also arise, such as fake news, cybercrime, and technological dependence. The future of the internet depends on balanced regulations, continuous innovation, and digital education so that its benefits can be enjoyed safely and inclusively.""",

    """Coffee is one of the most consumed beverages in the world and is part of Brazilian culture.""",

    """The Olympic Games are more than just a sporting event; they represent a celebration of unity, diversity, and human achievement. Athletes from around the world gather to compete at the highest level, showcasing not only physical skill but also resilience and determination. The Games have evolved over time, incorporating new disciplines and promoting values such as fair play and respect. Beyond the competitions, the Olympics foster cultural exchange, allowing nations to share traditions and build mutual understanding. Despite challenges such as political tensions and financial costs, the spirit of the Olympics continues to inspire millions, proving that sport can be a powerful force for peace and cooperation.""",

    """The Renaissance was a period of profound cultural, artistic, and scientific transformation in Europe between the 14th and 17th centuries. It marked the rediscovery of classical knowledge and the flourishing of human creativity. Artists like Leonardo da Vinci and Michelangelo produced masterpieces that continue to inspire admiration today, while scientists such as Galileo challenged traditional views of the universe. The invention of the printing press by Gutenberg revolutionized the spread of ideas, making books more accessible and fueling intellectual debates."""
]

# %%
# Estabelecer conexão com RabbitMQ
def get_connection():
  # retorna 'connection' com o cliente localhost do RabbitMQ
  return pika.BlockingConnection(pika.ConnectionParameters('localhost'))

# %%
# Criação de classe utilitária de simulação de cliente/producer ================
import uuid, json

QUEUE_NAME = "request_summarize_queue"

class Client:
  def __init__(self, client_id):
    # atributos de cliente/producer
    self.client_id = client_id
    self.connection = get_connection()
    self.channel = self.connection.channel()
    self.response = None

    # declara uma queue exclusiva e temporária, response queue
    result = self.channel.queue_declare(queue='', exclusive=True)
    self.callback_queue = result.method.queue

    # informando ao RabbitMQ que deve executar essa função ao receber uma nova mensagem
    self.channel.basic_consume(
        queue=self.callback_queue,
        on_message_callback=self.on_response,
        auto_ack=True
    )

  # função callback para receber a resposta da response queue
  def on_response(self, ch, method, props, body) -> None:
    if self.corr_id == props.correlation_id:
      self.response = body

  # função que simula uma requisição RPC
  def call(self, prompt: str) -> str:
    self.response = None
    # gera o id e payload do cliente
    self.corr_id = str(uuid.uuid4())
    payload = {"client_id": self.client_id, "prompt": prompt}
    # publica o payload em formato json na request_summarize_queue
    self.channel.basic_publish(
        exchange='',
        routing_key=QUEUE_NAME,
        properties=pika.BasicProperties(
            reply_to=self.callback_queue,
            correlation_id=self.corr_id
        ),
        body=json.dumps(payload)
    )
    # loop para verificar quando a resposta chega na response queue
    while self.response is None:
      self.connection.process_data_events()
    return self.response

# %%
# Função de requisição para o api gateway dos modelos =======================
import time, requests

API_URL = "https://zetta-faunlike-kindheartedly.ngrok-free.dev"
MODEL = "facebook_bart_large_cnn"
ENDPOINT_TEST = f"{API_URL}/summarize?model={MODEL}"

def summarizer(prompt: str, client_id: int):
  try:
    response = requests.post(ENDPOINT_TEST, json={"text": prompt})
    return response.json()["summary"]
  except Exception as e:
    print(f"\033[91m[ERROR]\033[0m Houve um problema com o teste das requisições, prompt/{1} client/{client_id}:\n {e}")

# %%
# Declarando Consumer (worker) =======================
import pika, time, json

# função para definição do consumer (worker) da request_summarize_queue
def consumer():
  connection = get_connection()
  channel = connection.channel()
  # verificar se a queue existe de forma idempotente (é uma boa prática, nesse caso, repetir o código de declaração da queue)
  channel.queue_declare(queue=QUEUE_NAME, durable=True)

  # função callback que será chamada quando uma message for recebida
  def callback(ch, method, props, body):
    payload = json.loads(body)
    client_id = payload["client_id"]
    prompt = payload["prompt"]

    print(f"\033[94m[Consumer]\033[0m Processando a request do cliente-{client_id}")
    summary = summarizer(prompt, client_id)

    response = {"client_id": client_id, "summary": summary}
    # publica a resposta na queue individual do cliente
    channel.basic_publish(
        exchange='',
        routing_key=props.reply_to,
        properties=pika.BasicProperties(correlation_id=props.correlation_id),
        body=json.dumps(response)
    )
    print(f"\033[94m[Consumer]\033[0m Request enviada do cliente-{client_id} para a queue {QUEUE_NAME}\n")
    ch.basic_ack(delivery_tag=method.delivery_tag)

  channel.basic_qos(prefetch_count=1)
  # informando ao RabbitMQ que essa função callback deve receber messages
  channel.basic_consume(
      queue=QUEUE_NAME,
      auto_ack=False,
      on_message_callback=callback
  )

  print('\033[94m[Consumer]\033[0m Aguardando messages...\n')
  channel.start_consuming()

# %%
# Função para salvar tempo das requisições de um determinado prompt em .csv ===========================
import csv, os

FOLDER = "tempos"
CSV_REQ_TIMES = f"./{FOLDER}/tempo_requisicoes_{MODEL}.csv"

def save_times_csv(request_prompt: str, request_response_data: dict) -> None:
  os.makedirs(FOLDER, exist_ok=True)

  with open(CSV_REQ_TIMES, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=[
        "prompt_id",
        "client_id",
        "prompt_entrada",
        "saida_resposta",
        "tamanho_prompt",
        "tamanho_saida",
        "tempo_s"
    ])
    writer.writeheader()
    writer.writerows(request_response_data)

    print(f"\033[93m[SYSTEM]\033[0m Arquivo com os tempos de requisição do modelo {MODEL} salvo com sucesso")

# %%
# Execução do consumer ===========
import threading, time, json

# quantidade de clientes/producers
CLIENTS_QUANT = 30
# armazena em formato dict os dados de respsota das requisições de cada cliente/producer
REQUEST_RESPONSE_DATAS = []

# iniciar o consumer em uma thread
threading.Thread(target=consumer).start()
def run_client(client: Client, prompt: str, prompt_id: int, request_response_datas: list) -> None:
  start = time.time()
  response = client.call(prompt)
  end = time.time()
  request_time = round(end - start, 4)

  summary_response = json.loads(response.decode("utf-8"))
  # armazena o tempo de requisição na list de REQUEST_RESPONSE_DATAS para usar posteriormente no salvamento do .csv
  request_response_datas.append({
      "prompt_id": prompt_id,
      "client_id": client.client_id,
      "prompt_entrada": prompt,
      "saida_resposta": summary_response["summary"],
      "tamanho_prompt": len(prompt),
      "tamanho_saida": len(summary_response["summary"]),
      "tempo_s": request_time
  })

  print(f"[Client-{client.client_id}] Recebeu uma resposta: {summary_response["summary"][:40]}... | Tempo: {request_time}")

for idx, prompt in enumerate(PROMPTS):
  print(f"\n\033[93m[SYSTEM]\033[0m Executando testes para o prompt {idx} ==============")
  # simulação de (n) clientes/producers
  clients = [Client(i) for i in range(CLIENTS_QUANT)]
  # inicia uma thread para cada cliente
  threads = []
  for c in clients:
    t = threading.Thread(target=run_client, args=(c, prompt, idx, REQUEST_RESPONSE_DATAS))
    threads.append(t)
    t.start()

  for t in threads:
    t.join()

# salva os tempos de requisição no .csv de tempos
save_times_csv(MODEL, REQUEST_RESPONSE_DATAS)
# Out:
# [SYSTEM] Executando testes para o prompt 0 ==============
# [Consumer] Aguardando messages...
#
# [Consumer] Processando a request do cliente-1
# [Consumer] Processando a request do cliente
consumer] Processando a request do cliente-1
# [Consumer] Processando a request do cliente-3
#
# [Consumer] Processando a request do cliente-0
# [Consumer] Processando a request do cliente-4
# [Consumer] Processando a request do cliente-5
# [Consumer] Processando a request do cliente-6
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
# [Client-0] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 2.19
# [Consumer] Processando a request do cliente-7
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-8
# [Client-4] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 4.6764
# [Client-3] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 7.4096
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-9
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-10
# [Client-6] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 11.4404
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-11
# [Client-5] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 12.9396
# [Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-12
# [Client-1] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 14.5708
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#
# [Client-2] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 16.3535
# [Consumer] Processando a request do cliente-13
# [Client-7] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 18.9538
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-14
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
#
# [Client-8] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 20.5282
# [Consumer] Processando a request do cliente-15
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
# [Client-9] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 22.029
#
# [Consumer] Processando a request do cliente-16
# [Client-10] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 24.0719
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-17
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
# [Client-11] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 25.3458
# [Consumer] Processando a request do cliente-18
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
# [Client-12] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 27.2302
#
# [Consumer] Processando a request do cliente-19
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-20
# [Client-13] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 28.8843
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Client-14] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 31.4505
# [Consumer] Processando a request do cliente-21
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
# [Client-15] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 34.5684
# [Consumer] Processando a request do cliente-22
# [Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
# [Client-16] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 37.1887
#
# [Consumer] Processando a request do cliente-23
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
# [Client-17] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 39.2747
#
# [Consumer] Processando a request do cliente-25
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
#
# [Client-18] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 40.6393
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
# [Client-19] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 42.3287
# [Consumer] Processando a request do cliente-27
# [Client-20] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 44.3423
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-26
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
#
# [Client-21] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 46.014
# [Consumer] Processando a request do cliente-28
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
# [Client-22] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 48.0992
# [Consumer] Processando a request do cliente-29
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
# [Client-23] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 49.9861
#
# [Client-25] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 51.5364[Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
#
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
# [Client-24] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 53.1583
#
# [Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
# [Client-27] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 54.7353
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
# [Client-26] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 56.6473
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
# [Client-28] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 58.4683
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
# [Client-29] Recebeu uma resposta: The Olympic Games are a celebration of u... | Tempo: 60.5069
#
# [SYSTEM] Executando testes para o prompt 7 ==============
#
# [Consumer] Processando a request do cliente-2
# [Consumer] Processando a request do cliente-1
# [Consumer] Processando a request do cliente-4
# [Consumer] Processando a request do cliente-3
# [Consumer] Processando a request do cliente-0
# [Consumer] Processando a request do cliente-6
# [Consumer] Processando a request do cliente-5
# [Consumer] Request enviada do cliente-3 para a queue request_summarize_queue
#
# [Client-3] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 1.9593
# [Consumer] Processando a request do cliente-7
# [Consumer] Request enviada do cliente-2 para a queue request_summarize_queue
#
# [Client-2] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 4.0659
# [Consumer] Processando a request do cliente-8
# [Consumer] Request enviada do cliente-4 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-9
# [Client-4] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 6.9978
# [Consumer] Request enviada do cliente-0 para a queue request_summarize_queue
#
# [Client-0] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 7.7035
# [Consumer] Processando a request do cliente-14
# [Consumer] Request enviada do cliente-5 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-12
# [Client-5] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 9.2121
# [Consumer] Request enviada do cliente-6 para a queue request_summarize_queue
#
# [Client-6] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 10.9788
# [Consumer] Processando a request do cliente-13
# [Consumer] Request enviada do cliente-1 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-11
# [Client-1] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 12.7859
# [Consumer] Request enviada do cliente-7 para a queue request_summarize_queue
# [Client-7] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 14.6052
#
# [Consumer] Processando a request do cliente-10
# [Consumer] Request enviada do cliente-8 para a queue request_summarize_queue
# [Client-8] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 15.7953
#
# [Consumer] Processando a request do cliente-15
# [Consumer] Request enviada do cliente-9 para a queue request_summarize_queue
#
# [Client-9] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 17.6403
# [Consumer] Processando a request do cliente-16
# [Consumer] Request enviada do cliente-14 para a queue request_summarize_queue
#
# [Client-14] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 19.5171
# [Consumer] Processando a request do cliente-17
# [Client-12] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 21.159
# [Consumer] Request enviada do cliente-12 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-18
# [Client-13] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 22.7732
# [Consumer] Request enviada do cliente-13 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-19
# [Consumer] Request enviada do cliente-11 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-20
# [Client-11] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 24.2676
# [Consumer] Request enviada do cliente-10 para a queue request_summarize_queue
#
# [Client-10] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 26.23
# [Consumer] Processando a request do cliente-21
# [Consumer] Request enviada do cliente-15 para a queue request_summarize_queue
#
# [Client-15] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 27.861
# [Consumer] Processando a request do cliente-22
# [Client-16] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 29.5882[Consumer] Request enviada do cliente-16 para a queue request_summarize_queue
#
#
# [Consumer] Processando a request do cliente-24
# [Consumer] Request enviada do cliente-17 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-23
# [Client-17] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 31.2771
# [Consumer] Request enviada do cliente-18 para a queue request_summarize_queue
# [Client-18] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 32.4971
#
# [Consumer] Processando a request do cliente-27
# [Client-19] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 34.3823
# [Consumer] Request enviada do cliente-19 para a queue request_summarize_queue
#
# [Consumer] Processando a request do cliente-25
# [Consumer] Request enviada do cliente-20 para a queue request_summarize_queue
#
# [Client-20] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 36.0278
# [Consumer] Processando a request do cliente-28
# [Consumer] Request enviada do cliente-21 para a queue request_summarize_queue
# [Client-21] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 37.1953
#
# [Consumer] Processando a request do cliente-26
# [Consumer] Request enviada do cliente-22 para a queue request_summarize_queue
#
# [Client-22] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 38.7901
# [Consumer] Processando a request do cliente-29
# [Consumer] Request enviada do cliente-24 para a queue request_summarize_queue
#
# [Client-24] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 39.9373
# [Consumer] Request enviada do cliente-23 para a queue request_summarize_queue
#
# [Client-23] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 41.763
# [Client-27] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 42.9339[Consumer] Request enviada do cliente-27 para a queue request_summarize_queue
#
#
# [Client-25] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 44.6028[Consumer] Request enviada do cliente-25 para a queue request_summarize_queue
#
#
# [Client-28] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 46.1585
# [Consumer] Request enviada do cliente-28 para a queue request_summarize_queue
#
# [Consumer] Request enviada do cliente-26 para a queue request_summarize_queue
#
# [Client-26] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 47.5656
# [Consumer] Request enviada do cliente-29 para a queue request_summarize_queue
#
# [Client-29] Recebeu uma resposta: The Renaissance was a period of profound... | Tempo: 48.7529
# [SYSTEM] Arquivo com os tempos de requisição do modelo facebook_bart_large_cnn salvo com sucesso

# %%
from google.colab import data_table
import pandas as pd
import numpy as np
import statistics

df = pd.read_csv(f"./tempos/tempo_requisicoes_{MODEL}.csv")
display(df)
# Out:
#      prompt_id  client_id                                     prompt_entrada  \
# 0            0          0  Solar energy is one of the most promising rene...
# 1            0          2  Solar energy is one of the most promising rene...
# 2            0          4  Solar energy is one of the most promising rene...
# 3            0          1  Solar energy is one of the most promising rene...
# 4            0          3  Solar energy is one of the most promising rene...
# ..         ...        ...                                                ...
# 235          7         27  The Renaissance was a period of profound cultu...
# 236          7         25  The Renaissance was a period of profound cultu...
# 237          7         28  The Renaissance was a period of profound cultu...
# 238          7         26  The Renaissance was a period of profound cultu...
# 239          7         29  The Renaissance was a period of profound cultu...
#
#                                         saida_resposta  tamanho_prompt  \
# 0    Brazil has one of the largest solar potentials...             779
# 1    Brazil has one of the largest solar potentials...             779
# 2    Brazil has one of the largest solar potentials...             779
# 3    Brazil has one of the largest solar potentials...             779
# 4    Brazil has one of the largest solar potentials...             779
# ..                                                 ...             ...
# 235  The Renaissance was a period of profound cultu...             567
# 236  The Renaissance was a period of profound cultu...             567
# 237  The Renaissance was a period of profound cultu...             567
# 238  The Renaissance was a period of profound cultu...             567
# 239  The Renaissance was a period of profound cultu...             567
#
#      tamanho_saida  tempo_s
# 0              405   6.2772
# 1              405   8.1857
# 2              405  10.1691
# 3              405  11.4698
# 4              405  13.5046
# ..             ...      ...
# 235            372  42.9339
# 236            372  44.6028
# 237            372  46.1585
# 238            372  47.5656
# 239            372  48.7529
#
# [240 rows x 7 columns]

# %%
# !sudo rabbitmqctl stop_app
# !sudo rabbitmqctl reset
# !sudo rabbitmqctl start_app
# Out:
# ERROR:pika.adapters.blocking_connection:Unexpected connection close detected: ConnectionClosedByBroker: (320) "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'"
# ERROR:pika.adapters.blocking_connection:Unexpected connection close detected: ConnectionClosedByBroker: (320) "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'"
# Exception in thread Thread-45 (consumer):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
# Exception in thread Thread-21 (consumer):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipython-input-279502506.py", line 39, in consumer
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 1883, in start_consuming
# ERROR:pika.adapters.blocking_connection:Unexpected connection close detected: ConnectionClosedByBroker: (320) "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'"
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipython-input-279502506.py", line 39, in consumer
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 1883, in start_consuming
# Exception in thread Thread-9 (consumer):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
# ERROR:pika.adapters.blocking_connection:Unexpected connection close detected: ConnectionClosedByBroker: (320) "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'"
#     self._process_data_events(time_limit=None)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 2044, in _process_data_events
#     self._process_data_events(time_limit=None)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 2044, in _process_data_events
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
# Exception in thread Thread-33 (consumer):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipython-input-279502506.py", line 39, in consumer
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 1883, in start_consuming
#     self._process_data_events(time_limit=None)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 2044, in _process_data_events
#     self.connection.process_data_events(time_limit=time_limit)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 842, in process_data_events
#     self.connection.process_data_events(time_limit=time_limit)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 842, in process_data_events
#     self._flush_output(common_terminator)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 523, in _flush_output
#     raise self._closed_result.value.error
# pika.exceptions.ConnectionClosedByBroker: (320, "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'")
# ERROR:pika.adapters.blocking_connection:Unexpected connection close detected: ConnectionClosedByBroker: (320) "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'"
#     self._flush_output(common_terminator)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 523, in _flush_output
#     self.connection.process_data_events(time_limit=time_limit)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 842, in process_data_events
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipython-input-279502506.py", line 39, in consumer
# Exception in thread Thread-116 (run_client):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     raise self._closed_result.value.error
# pika.exceptions.ConnectionClosedByBroker: (320, "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'")
#     self._flush_output(common_terminator)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 523, in _flush_output
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 1883, in start_consuming
#     raise self._closed_result.value.error
# pika.exceptions.ConnectionClosedByBroker: (320, "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'")
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipython-input-476111775.py", line 14, in run_client
#     self._process_data_events(time_limit=None)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 2044, in _process_data_events
#     self.connection.process_data_events(time_limit=time_limit)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 842, in process_data_events
#     self._flush_output(common_terminator)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 523, in _flush_output
#   File "/tmp/ipython-input-429780935.py", line 48, in call
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 845, in process_data_events
#     raise self._closed_result.value.error
# pika.exceptions.ConnectionClosedByBroker: (320, "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'")
#     self._flush_output(timer.is_ready, common_terminator)
#   File "/usr/local/lib/python3.12/dist-packages/pika/adapters/blocking_connection.py", line 523, in _flush_output
#     raise self._closed_result.value.error
# pika.exceptions.ConnectionClosedByBroker: (320, "CONNECTION_FORCED - broker forced connection closure with reason 'shutdown'")
# Stopping rabbit application on node rabbit@1b553ff1b740 ...
# Resetting node rabbit@1b553ff1b740 ...
# Starting node rabbit@1b553ff1b740 ...

# %%
# !sudo rabbitmqctl delete_queue summarize_queue
